# %%
# Importing necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# loading the dataset
data = pd.read_csv("C:/Users/manik/Downloads/Survey_Data - Sheet2 (1).csv")

# %%
#displaying few records 
data.head()
# Out:
#   Please select your  age (in years) below :  \
# 0                                      18-22
# 1                                      18-22
# 2                                      18-22
# 3                                      18-22
# 4                                      18-22
#
#   How often do you find that you stay online longer than you intended?  [Your response]  \
# 0                                             Always
# 1                                             Always
# 2                                             Always
# 3                                             Always
# 4                                             Always
#
#   How often do your grades or school work suffer because of the amount of time you spend online?  [Your response]  \
# 0                                              Often
# 1                                              Often
# 2                                             Always
# 3                                             Always
# ...

# %%
# handling missing values
data.isnull().sum()
data = data.fillna(0)

# %%
#dropping duplicates
data.drop_duplicates(inplace=True)

# %%
from sklearn.preprocessing import LabelEncoder

# create a LabelEncoder object
le = LabelEncoder()

# encode categorical variables in your DataFrame
data["Highest level of eduaction attained :"] = le.fit_transform(data["Highest level of eduaction attained :"])
data["Field of education / profession :"] = le.fit_transform(data["Field of education / profession :"])
data["Type of settlement : "] = le.fit_transform(data["Type of settlement : "])

# %%
data.to_csv('Cleaned_survey2.csv', index=False)

# %%
target = data['How often do you find that you stay online longer than you intended?  [Your response]']
print(set(target))
# Out:
# {'Frequently', 'Often', 'Rarely', 'Not Applicable', 'Occasionally', 'Always'}

# %%
X = data.drop(columns=['Field of education / profession :'])
y = data['When did you start using social media actively?']

# Split data into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y)

# %%
print("X_train shape:", X_train.shape)
print("y_train shape:", y_train.shape)
print("X_test shape:", X_test.shape)
print("y_test shape:", y_test.shape)
# Out:
# X_train shape: (245, 16)
# y_train shape: (245,)
# X_test shape: (62, 16)
# y_test shape: (62,)
